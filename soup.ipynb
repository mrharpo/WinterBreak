# %%
from bs4 import BeautifulSoup

# %%
locations = """<Locations>
    <Location id="275" name="session" start="b-3694" end="b837120" flags="IsSessionRange" locked="0" timestamp="1702098101" cue="0"/>
    <Location id="416" name="11" start="b7680" end="b7680" flags="IsMark" locked="0" timestamp="1702098647" cue="0"/>
    <Location id="467" name="12" start="b46080" end="b46080" flags="IsMark" locked="0" timestamp="1702098746" cue="0"/>
    <Location id="476" name="13" start="b76800" end="b76800" flags="IsMark" locked="0" timestamp="1702098759" cue="0"/>
    <Location id="485" name="13.1" start="b92160" end="b92160" flags="IsMark" locked="0" timestamp="1702098764" cue="0"/>
    <Location id="506" name="14" start="b107520" end="b107520" flags="IsMark" locked="0" timestamp="1702098787" cue="0"/>
    <Location id="515" name="14.5" start="b122880" end="b122880" flags="IsMark" locked="0" timestamp="1702098793" cue="0"/>
    <Location id="524" name="15" start="b138240" end="b138240" flags="IsMark" locked="0" timestamp="1702098804" cue="0"/>
    <Location id="533" name="16" start="b145920" end="b145920" flags="IsMark" locked="0" timestamp="1702098811" cue="0"/>
    <Location id="545" name="17" start="b153600" end="b153600" flags="IsMark" locked="0" timestamp="1702098819" cue="0"/>
    <Location id="562" name="18" start="b161280" end="b161280" flags="IsMark" locked="0" timestamp="1702098842" cue="0"/>
    <Location id="571" name="19" start="b168960" end="b168960" flags="IsMark" locked="0" timestamp="1702098847" cue="0"/>
    <Location id="596" name="23" start="b276480" end="b276480" flags="IsMark" locked="0" timestamp="1702099288" cue="0"/>
    <Location id="604" name="20" start="b245760" end="b245760" flags="IsMark" locked="0" timestamp="1702099377" cue="0"/>
    <Location id="1192" name="10.5" start="b0" end="b0" flags="IsMark" locked="0" timestamp="1702104046" cue="0"/>
    <Location id="1241" name="19.2" start="b192000" end="b192000" flags="IsMark" locked="0" timestamp="1702104197" cue="0"/>
    <Location id="1347" name="19.9" start="b238080" end="b238080" flags="IsMark" locked="0" timestamp="1702104353" cue="0"/>
    <Location id="1360" name="21" start="b253440" end="b253440" flags="IsMark" locked="0" timestamp="1702104427" cue="0"/>
    <Location id="1369" name="22" start="b261120" end="b261120" flags="IsMark" locked="0" timestamp="1702104439" cue="0"/>
    <Location id="1394" name="23.9" start="b314880" end="b314880" flags="IsMark" locked="0" timestamp="1702104581" cue="0"/>
    <Location id="1403" name="24" start="b322560" end="b322560" flags="IsMark" locked="0" timestamp="1702104587" cue="0"/>
    <Location id="1412" name="25" start="b337920" end="b337920" flags="IsMark" locked="0" timestamp="1702104603" cue="0"/>
    <Location id="1430" name="26" start="b360960" end="b360960" flags="IsMark" locked="0" timestamp="1702104635" cue="0"/>
    <Location id="1439" name="27" start="b414720" end="b414720" flags="IsMark" locked="0" timestamp="1702104655" cue="0"/>
    <Location id="1448" name="27.1" start="b422400" end="b422400" flags="IsMark" locked="0" timestamp="1702104668" cue="0"/>
    <Location id="1476" name="28" start="b460800" end="b460800" flags="IsMark" locked="0" timestamp="1702104699" cue="0"/>
    <Location id="1489" name="28.5" start="b476160" end="b476160" flags="IsMark" locked="0" timestamp="1702104756" cue="0"/>
    <Location id="1498" name="30" start="b506880" end="b506880" flags="IsMark" locked="0" timestamp="1702104780" cue="0"/>
    <Location id="1510" name="31" start="b522240" end="b522240" flags="IsMark" locked="0" timestamp="1702104784" cue="0"/>
    <Location id="1522" name="32" start="b537600" end="b537600" flags="IsMark" locked="0" timestamp="1702104802" cue="0"/>
    <Location id="1531" name="32.5" start="b560640" end="b560640" flags="IsMark" locked="0" timestamp="1702104815" cue="0"/>
    <Location id="1543" name="33" start="b568320" end="b568320" flags="IsMark" locked="0" timestamp="1702104822" cue="0"/>
    <Location id="1552" name="33.5" start="b606720" end="b606720" flags="IsMark" locked="0" timestamp="1702104848" cue="0"/>
    <Location id="1561" name="34" start="b614400" end="b614400" flags="IsMark" locked="0" timestamp="1702104857" cue="0"/>
    <Location id="1570" name="35" start="b629760" end="b629760" flags="IsMark" locked="0" timestamp="1702104912" cue="0"/>
    <Location id="1587" name="36" start="b645120" end="b645120" flags="IsMark" locked="0" timestamp="1702104930" cue="0"/>
    <Location id="1596" name="36.5" start="b683520" end="b683520" flags="IsMark" locked="0" timestamp="1702104956" cue="0"/>
    <Location id="1610" name="37" start="b691200" end="b691200" flags="IsMark" locked="0" timestamp="1702104963" cue="0"/>
    <Location id="1619" name="40" start="b706560" end="b706560" flags="IsMark" locked="0" timestamp="1702104976" cue="0"/>
    <Location id="1633" name="19.1" start="b184320" end="b184320" flags="IsMark" locked="0" timestamp="1702166553" cue="0"/>
    <Location id="1659" name="25.5" start="b353280" end="b353280" flags="IsMark" locked="0" timestamp="1702166738" cue="0"/>
    <Location id="1694" name="27.5" start="b437760" end="b437760" flags="IsMark" locked="0" timestamp="1702166839" cue="0"/>
    <Location id="2677" name="29" start="b499200" end="b499200" flags="IsMark" locked="0" timestamp="1702170619" cue="0"/>
    <Location id="2681" name="29.5" start="b503040" end="b503040" flags="IsMark" locked="0" timestamp="1702170621" cue="0"/>
    <Location id="2709" name="12.9" start="b69120" end="b69120" flags="IsMark" locked="0" timestamp="1702261982" cue="0"/>
    <Location id="2718" name="19.3" start="b199680" end="b199680" flags="IsMark" locked="0" timestamp="1702262051" cue="0"/>
  </Locations>"""

soup = BeautifulSoup(locations, "xml")

# %%
markers = {}

for location in soup.find_all("Location"):
    name = location["name"]
    start = int(location["start"][1:]) // 7680
    # markers[name] = start
    print(f"{name}, {start}")
# Out:
# session -1
# 11 1
# 12 6
# 13 10
# 13.1 12
# 14 14
# 14.5 16
# 15 18
# 16 19
# 17 20
# 18 21
# 19 22
# 23 36
# 20 32
# 10.5 0
# 19.2 25
# 19.9 31
# 21 33
# 22 34
# 23.9 41
# 24 42
# 25 44
# 26 47
# 27 54
# 27.1 55
# 28 60
# 28.5 62
# 30 66
# 31 68
# 32 70
# 32.5 73
# 33 74
# 33.5 79
# 34 80
# 35 82
# 36 84
# 36.5 89
# 37 90
# 40 92
# 19.1 24
# 25.5 46
# 27.5 57
# 29 65
# 29.5 65
# 12.9 9
# 19.3 26

# %%
markers
# Out:
# {'session': -0.48098958333333336,
#  '11': 1.0,
#  '12': 6.0,
#  '13': 10.0,
#  '13.1': 12.0,
#  '14': 14.0,
#  '14.5': 16.0,
#  '15': 18.0,
#  '16': 19.0,
#  '17': 20.0,
#  '18': 21.0,
#  '19': 22.0,
#  '23': 36.0,
#  '20': 32.0,
#  '10.5': 0.0,
#  '19.2': 25.0,
#  '19.9': 31.0,
#  '21': 33.0,
#  '22': 34.0,
#  '23.9': 41.0,
#  '24': 42.0,
#  '25': 44.0,
#  '26': 47.0,
#  '27': 54.0,
#  '27.1': 55.0,
#  '28': 60.0,
#  '28.5': 62.0,
#  '30': 66.0,
#  '31': 68.0,
#  '32': 70.0,
#  '32.5': 73.0,
#  '33': 74.0,
#  '33.5': 79.0,
#  '34': 80.0,
#  '35': 82.0,
#  '36': 84.0,
#  '36.5': 89.0,
#  '37': 90.0,
#  '40': 92.0,
#  '19.1': 24.0,
#  '25.5': 46.0,
#  '27.5': 57.0,
#  '29': 65.0,
#  '29.5': 65.5,
#  '12.9': 9.0,
#  '19.3': 26.0}
